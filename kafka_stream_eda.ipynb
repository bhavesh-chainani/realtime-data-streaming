# %%
# kafka_stream.py eda

from datetime import datetime
from airflow import DAG
from airflow.operators.python import PythonOperator
import json
import requests

# %%
default_args = {
    'owner': 'airscholar',
    'start_date': datetime(2023, 9, 3, 10, 00)
}

# %%
def stream_data():
    res = requests.get('https://randomuser.me/api/')
    res = res.json()['results'][0]
    print(res)

# %%
stream_data()
# Out:
# {'gender': 'male', 'name': {'title': 'Mr', 'first': 'Gabin', 'last': 'Gerard'}, 'location': {'street': {'number': 9685, 'name': 'Rue Duquesne'}, 'city': 'Avignon', 'state': 'Calvados', 'country': 'France', 'postcode': 47805, 'coordinates': {'latitude': '-16.4419', 'longitude': '-47.1267'}, 'timezone': {'offset': '-1:00', 'description': 'Azores, Cape Verde Islands'}}, 'email': 'gabin.gerard@example.com', 'login': {'uuid': '566fe226-3b0c-42ec-9924-92c1d015e77c', 'username': 'blackfish624', 'password': 'megapass', 'salt': 'mSdVi6Wu', 'md5': '0770c5e41b2b19e3ff9ffd39d7849c20', 'sha1': 'ceaa866258e0cc1073a85db6e4195d71de7e2d74', 'sha256': 'e1d904c35b743c5c16021b67972ef4f0aec0a1585e2161b687cfdf4f2e68281e'}, 'dob': {'date': '1953-02-16T08:54:01.741Z', 'age': 72}, 'registered': {'date': '2017-05-16T04:50:30.671Z', 'age': 7}, 'phone': '05-01-38-44-71', 'cell': '06-23-39-31-07', 'id': {'name': 'INSEE', 'value': '1530145822997 82'}, 'picture': {'large': 'https://randomuser.me/api/portraits/men/6.jpg', 'medium': 'https://randomuser.me/api/portraits/med/men/6.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/6.jpg'}, 'nat': 'FR'}

# %%
with DAG('user_automation',
         default_args=default_args,
         schedule_interval='@daily',
         catchup=False) as dag:
    
    streaming_task = PythonOperator(
        task_id = 'stream_data_from_api',
        python_callable=stream_data
    )
